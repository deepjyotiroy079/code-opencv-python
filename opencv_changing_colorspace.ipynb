# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('Images/image1.png')

# %%
plt.imshow(img)

# %%
corrected_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(corrected_img)

# %%
corrected_img = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)
plt.imshow(corrected_img)
